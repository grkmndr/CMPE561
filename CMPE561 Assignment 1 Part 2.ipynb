# %%
# coding: utf-8

# In[438]:

import re
import numpy as np
import os
import codecs

rootDir = '.'
TOTAL_TRAINING_DOCUMENT_COUNT = 0
DOCUMENT_COUNT_PER_AUTHOR = {}
VOCABULARY = set()
authorBags = {}
authorFeatures = {}

def tokenize(text, choice): #if choice is 1 return the bag of words, else return the unique words with their counts
    bag = re.split('\W+', text)
    counts = {}
    for x in set(bag):
        counts.update({x:bag.count(x)})
    if choice:
        return bag
    else:
        return counts

    
for dirName, subdirList, fileList in os.walk(rootDir+'/trainingSet'):
    if(dirName != './trainingSet'):
        currDir = dirName[14:]
        
        authorBags.update({currDir:{}})
        authorFeatures.update({currDir:{'wordCount':0, #wordCount: total word count for the author.
                                        'sentenceCount':0, #sentenceCount: sentence count per document for the author.
                                        'wordLength':0, #wordLength: average word length for the author.
                                        'commaCount':0, #commaCount: average number of commas per sentence for the author.
                                        'exclamationCount':0, #exclamationCount: average number of exclamation marks per sentence for the author.
                                        'questionCount':0 #questionCount: average number of question marks per sentence for the author.
                                       }}) 



        #print(authorBags)
        fileCount = len(fileList)
        ##print(dirName)
        DOCUMENT_COUNT_PER_AUTHOR.update({currDir:0})
        
        for fname in fileList:
            TOTAL_TRAINING_DOCUMENT_COUNT += 1
            DOCUMENT_COUNT_PER_AUTHOR[currDir] += 1
            text = ''
            with codecs.open(dirName+'/'+fname, 'r', 'ISO-8859-9') as myfile:
                ##print(dirName+'/'+fname)
                text = myfile.read().lower()
                
                authorFeatures[currDir]['sentenceCount'] += text.count('.')
                authorFeatures[currDir]['commaCount'] += text.count(',')
                authorFeatures[currDir]['exclamationCount'] += text.count('!')
                authorFeatures[currDir]['questionCount'] += text.count('?')

                bagCounts = tokenize(text,0)
                for word in bagCounts:
                    authorFeatures[currDir]['wordCount'] += bagCounts[word]
                    authorFeatures[currDir]['wordLength'] += bagCounts[word]*len(word)
                    newWord = ''
                    if word.isdigit(): newWord = 'NUMBER'
                    else: newWord = word
                    
                    if newWord in authorBags[currDir]:
                        authorBags[currDir][newWord] += bagCounts[word]
                    else:
                        authorBags[currDir].update({newWord:bagCounts[word]})
        
        if '' in authorBags[currDir]: del authorBags[currDir]['']
            
        VOCABULARY.update(authorBags[currDir].keys())

        authorFeatures[currDir]['commaCount'] /= authorFeatures[currDir]['sentenceCount']
        authorFeatures[currDir]['exclamationCount'] /= authorFeatures[currDir]['sentenceCount']
        authorFeatures[currDir]['questionCount'] /= authorFeatures[currDir]['sentenceCount']
        authorFeatures[currDir]['sentenceCount'] /= DOCUMENT_COUNT_PER_AUTHOR[currDir]
        authorFeatures[currDir]['wordLength'] /= authorFeatures[currDir]['wordCount']
        authorFeatures[currDir]['wordCount'] /= DOCUMENT_COUNT_PER_AUTHOR[currDir]



# In[ ]:

# %%
# In[439]:

def text_class(text): 
    maxProb = -float('Inf')
    maxAuth = ''
    vocabSize = len(VOCABULARY)

    sentenceCount = text.count('.')
    commaCount = text.count(',')
    exclamationCount = text.count('!')
    questionCount = text.count('?')
    
    tokens = tokenize(text,1)
    
    for authName in authorBags:
        n = sum(authorBags[authName].values())
        #print(n , authName)
        prob = 0
        wordLength = 0
        
        for token in tokens:
            wordLength += len(token)
            smoother = 0.004
            if token in authorBags[authName]:
                tokenProb = (authorBags[authName][token]+smoother)/(n+smoother*vocabSize)
            else:
                tokenProb = smoother/(n+smoother*vocabSize)
            prob = prob + np.log(tokenProb)
            #print('tokenProb = ' , tokenProb)
        
        wordLength /= len(tokens)
        
        authorProb = DOCUMENT_COUNT_PER_AUTHOR[authName] / TOTAL_TRAINING_DOCUMENT_COUNT
        #print('authorProb = ', np.log(authorProb))
        prob += np.log(authorProb)
        prob -= abs(authorFeatures[authName]['wordCount'] - len(tokens))
        prob -= abs(authorFeatures[authName]['sentenceCount'] - sentenceCount)
        prob -= 10*abs(authorFeatures[authName]['wordLength'] - wordLength)
        prob -= 100*abs(authorFeatures[authName]['commaCount'] - commaCount/sentenceCount)
        prob -= 1000*abs(authorFeatures[authName]['exclamationCount'] - exclamationCount/sentenceCount)
        prob -= 1000*abs(authorFeatures[authName]['questionCount'] - questionCount/sentenceCount)

        #print(wordLength)
        #print(abs(authorFeatures[authName]['wordLength'] - wordLength))
        if prob > maxProb:
            maxProb = prob
            maxAuth = authName
        #print('Prob for auth ',authName, prob)
    
    #print(maxAuth)
    return maxAuth

# %%
# In[440]:

"""with codecs.open('./testSet/ahmetAltan/M7.txt', 'r', 'ISO-8859-9') as myfile:
    text = myfile.read()
    bagCounts = tokenize(text,1)
    text_class(bagCounts)"""

success = 0
totalTrial = 0
for dirName, subdirList, fileList in os.walk(rootDir+'/testSet'):
    if(dirName != './testSet'):
        currDir = dirName[10:]
        for fname in fileList:
            text = ''
            with codecs.open(dirName+'/'+fname, 'r', 'ISO-8859-9') as myfile:
                #print(dirName+'/'+fname)
                text = myfile.read().lower()
                auth = text_class(text)
                totalTrial += 1
                if auth == dirName[10:]:
                    #print('success')
                    success +=1
                #else:
                    #print('fail')

# %%
# In[441]:

print('Success rate :', success/ totalTrial)
# Out:
# Success rate : 0.7554945054945055

# %%
# In[442]:
#0.7527472527472527
with codecs.open('./testSet/abbasGuclu/13.txt', 'r', 'ISO-8859-9') as myfile:
    text = myfile.read()
    bagCounts = tokenize(text,1)
    text_class(text)

# %%
authorFeatures
# Out:
# {'abbasGuclu': {'commaCount': 0.75,
#   'exclamationCount': 0.0397196261682243,
#   'questionCount': 0.1705607476635514,
#   'sentenceCount': 47.55555555555556,
#   'wordCount': 560.1111111111111,
#   'wordLength': 5.796468954572505},
#  'abdullahAymaz': {'commaCount': 0.3299492385786802,
#   'exclamationCount': 0.02030456852791878,
#   'questionCount': 0.007614213197969543,
#   'sentenceCount': 65.66666666666667,
#   'wordCount': 549.3333333333334,
#   'wordLength': 6.023361650485437},
#  'ahmetAltan': {'commaCount': 1.1746724890829694,
#   'exclamationCount': 0.0,
#   'questionCount': 0.18777292576419213,
#   'sentenceCount': 38.166666666666664,
#   'wordCount': 542.5,
#   'wordLength': 6.282642089093702},
#  'ahmetHakan': {'commaCount': 0.19400499583680267,
#   'exclamationCount': 0.004995836802664446,
#   'questionCount': 0.04829308909242298,
#   'sentenceCount': 133.44444444444446,
#   'wordCount': 525.0,
#   'wordLength': 5.859259259259259},
#  'aliBulac': {'commaCount': 0.9336734693877551,
#   'exclamationCount': 0.00510204081632653,
#   'questionCount': 0.025510204081632654,
#   'sentenceCount': 32.666666666666664,
#   'wordCount': 528.8333333333334,
#   'wordLength': 6.260951780649227},
#  'atillaDorsay': {'commaCount': 0.7857142857142857,
#   'exclamationCount': 0.025714285714285714,
#   'questionCount': 0.037142857142857144,
#   'sentenceCount': 38.888888888888886,
#   'wordCount': 440.55555555555554,
#   'wordLength': 5.765952080706179},
#  'ayseArman': {'commaCount': 0.5919343814080656,
#   'exclamationCount': 0.05263157894736842,
#   'questionCount': 0.10321257689678742,
#   'sentenceCount': 162.55555555555554,
#   'wordCount': 1089.6666666666667,
#   'wordLength': 5.683083511777302},
#  'balcicekPamir': {'commaCount': 0.48676470588235293,
#   'exclamationCount': 0.039705882352941174,
#   'questionCount': 0.12058823529411765,
#   'sentenceCount': 75.55555555555556,
#   'wordCount': 514.2222222222222,
#   'wordLength': 5.886884183232498},
#  'bekirCoskun': {'commaCount': 0.2200557103064067,
#   'exclamationCount': 0.002785515320334262,
#   'questionCount': 0.025069637883008356,
#   'sentenceCount': 59.833333333333336,
#   'wordCount': 191.16666666666666,
#   'wordLength': 6.006974716652136},
#  'bulentKorucu': {'commaCount': 0.491869918699187,
#   'exclamationCount': 0.0040650406504065045,
#   'questionCount': 0.06504065040650407,
#   'sentenceCount': 41.0,
#   'wordCount': 478.1666666666667,
#   'wordLength': 6.673405367723945},
#  'canDundar': {'commaCount': 0.39285714285714285,
#   'exclamationCount': 0.012987012987012988,
#   'questionCount': 0.045454545454545456,
#   'sentenceCount': 51.333333333333336,
#   'wordCount': 386.0,
#   'wordLength': 5.887737478411053},
#  'cemSuer': {'commaCount': 0.8032786885245902,
#   'exclamationCount': 0.0,
#   'questionCount': 0.01639344262295082,
#   'sentenceCount': 10.166666666666666,
#   'wordCount': 148.16666666666666,
#   'wordLength': 6.057367829021373},
#  'cemilErtem': {'commaCount': 0.9121338912133892,
#   'exclamationCount': 0.012552301255230125,
#   'questionCount': 0.0502092050209205,
#   'sentenceCount': 39.833333333333336,
#   'wordCount': 640.6666666666666,
#   'wordLength': 6.190426638917794},
#  'cengizCandar': {'commaCount': 1.1633986928104576,
#   'exclamationCount': 0.0032679738562091504,
#   'questionCount': 0.10457516339869281,
#   'sentenceCount': 51.0,
#   'wordCount': 967.5,
#   'wordLength': 6.107665805340224},
#  'cetinAltan': {'commaCount': 0.8121590023382697,
#   'exclamationCount': 0.005455962587685113,
#   'questionCount': 0.049103663289166016,
#   'sentenceCount': 71.27777777777777,
#   'wordCount': 585.8888888888889,
#   'wordLength': 6.0356533282761236},
#  'deryaSazak': {'commaCount': 1.123076923076923,
#   'exclamationCount': 0.05384615384615385,
#   'questionCount': 0.06153846153846154,
#   'sentenceCount': 21.666666666666668,
#   'wordCount': 367.0,
#   'wordLength': 6.316076294277929},
#  'doganHizlan': {'commaCount': 0.9204545454545454,
#   'exclamationCount': 0.0,
#   'questionCount': 0.030303030303030304,
#   'sentenceCount': 29.333333333333332,
#   'wordCount': 395.55555555555554,
#   'wordLength': 6.248595505617978},
#  'eceTemelkuran': {'commaCount': 0.5720524017467249,
#   'exclamationCount': 0.10043668122270742,
#   'questionCount': 0.14410480349344978,
#   'sentenceCount': 38.166666666666664,
#   'wordCount': 397.1666666666667,
#   'wordLength': 5.954259336970206},
#  'ekremDumanli': {'commaCount': 0.4587087087087087,
#   'exclamationCount': 0.03528528528528529,
#   'questionCount': 0.08483483483483484,
#   'sentenceCount': 74.0,
#   'wordCount': 914.2777777777778,
#   'wordLength': 6.044418788357538},
#  'elifSafak': {'commaCount': 0.4847870182555781,
#   'exclamationCount': 0.034482758620689655,
#   'questionCount': 0.034482758620689655,
#   'sentenceCount': 82.16666666666667,
#   'wordCount': 686.0,
#   'wordLength': 5.88338192419825},
#  'emreAkoz': {'commaCount': 0.5971867007672634,
#   'exclamationCount': 0.03580562659846547,
#   'questionCount': 0.10358056265984655,
#   'sentenceCount': 43.44444444444444,
#   'wordCount': 383.44444444444446,
#   'wordLength': 6.051144595769342},
#  'emreKongar': {'commaCount': 0.6804733727810651,
#   'exclamationCount': 0.026627218934911243,
#   'questionCount': 0.40236686390532544,
#   'sentenceCount': 37.55555555555556,
#   'wordCount': 381.22222222222223,
#   'wordLength': 6.346837656659866},
#  'ergunBabahan': {'commaCount': 0.751269035532995,
#   'exclamationCount': 0.02030456852791878,
#   'questionCount': 0.06598984771573604,
#   'sentenceCount': 32.833333333333336,
#   'wordCount': 367.0,
#   'wordLength': 5.990917347865577},
#  'ertugrulOzkok': {'commaCount': 0.5519287833827893,
#   'exclamationCount': 0.0,
#   'questionCount': 0.05637982195845697,
#   'sentenceCount': 56.166666666666664,
#   'wordCount': 459.0,
#   'wordLength': 5.919026870007262},
#  'fatihAltayli': {'commaCount': 0.47619047619047616,
#   'exclamationCount': 0.004578754578754579,
#   'questionCount': 0.07326007326007326,
#   'sentenceCount': 60.666666666666664,
#   'wordCount': 581.8333333333334,
#   'wordLength': 5.85247780005729},
#  'fehmiKoru': {'commaCount': 0.6228070175438597,
#   'exclamationCount': 0.0,
#   'questionCount': 0.05263157894736842,
#   'sentenceCount': 38.0,
#   'wordCount': 465.0,
#   'wordLength': 6.477060931899642},
#  'fikretBila': {'commaCount': 0.6652173913043479,
#   'exclamationCount': 0.0,
#   'questionCount': 0.04782608695652174,
#   'sentenceCount': 38.333333333333336,
#   'wordCount': 484.3333333333333,
#   'wordLength': 6.096696490020647},
#  'fundaOzkan': {'commaCount': 1.054421768707483,
#   'exclamationCount': 0.003401360544217687,
#   'questionCount': 0.05102040816326531,
#   'sentenceCount': 49.0,
#   'wordCount': 662.8333333333334,
#   'wordLength': 6.081216997736988},
#  'gulseBirsel': {'commaCount': 1.9494949494949494,
#   'exclamationCount': 0.5151515151515151,
#   'questionCount': 0.10101010101010101,
#   'sentenceCount': 33.0,
#   'wordCount': 606.6666666666666,
#   'wordLength': 6.001923076923077},
#  'guneriCivaoglu': {'commaCount': 0.3632286995515695,
#   'exclamationCount': 0.006726457399103139,
#   'questionCount': 0.04708520179372197,
#   'sentenceCount': 74.33333333333333,
#   'wordCount': 533.6666666666666,
#   'wordLength': 6.168019987507807},
#  'hakkiDevrim': {'commaCount': 0.7525325615050651,
#   'exclamationCount': 0.05788712011577424,
#   'questionCount': 0.08393632416787265,
#   'sentenceCount': 76.77777777777777,
#   'wordCount': 772.6666666666666,
#   'wordLength': 6.0842680471670985},
#  'hasanCemal': {'commaCount': 0.45080091533180777,
#   'exclamationCount': 0.020594965675057208,
#   'questionCount': 0.09382151029748284,
#   'sentenceCount': 72.83333333333333,
#   'wordCount': 478.5,
#   'wordLength': 5.952629745733194},
#  'hasanPulur': {'commaCount': 1.180952380952381,
#   'exclamationCount': 0.11904761904761904,
#   'questionCount': 0.14285714285714285,
#   'sentenceCount': 35.0,
#   'wordCount': 382.6666666666667,
#   'wordLength': 5.895034843205575},
#  'hasmetBabaoglu': {'commaCount': 0.32142857142857145,
#   'exclamationCount': 0.20454545454545456,
#   'questionCount': 0.06493506493506493,
#   'sentenceCount': 51.333333333333336,
#   'wordCount': 344.8333333333333,
#   'wordLength': 5.932817786370227},
#  'hekimogluIsmail': {'commaCount': 0.6746268656716418,
#   'exclamationCount': 0.03880597014925373,
#   'questionCount': 0.08059701492537313,
#   'sentenceCount': 55.833333333333336,
#   'wordCount': 455.8333333333333,
#   'wordLength': 5.689213893967093},
#  'hincalUluc': {'commaCount': 0.41046831955922863,
#   'exclamationCount': 0.01652892561983471,
#   'questionCount': 0.06887052341597796,
#   'sentenceCount': 121.0,
#   'wordCount': 568.8333333333334,
#   'wordLength': 5.667154995605039},
#  'huseyinGulerce': {'commaCount': 0.9637462235649547,
#   'exclamationCount': 0.012084592145015106,
#   'questionCount': 0.0755287009063444,
#   'sentenceCount': 55.166666666666664,
#   'wordCount': 510.8333333333333,
#   'wordLength': 6.32300163132137},
#  'ismetBerkan': {'commaCount': 0.7878787878787878,
#   'exclamationCount': 0.006060606060606061,
#   'questionCount': 0.07272727272727272,
#   'sentenceCount': 27.5,
#   'wordCount': 407.0,
#   'wordLength': 6.06961506961507},
#  'mahfiEgilmez': {'commaCount': 0.3101449275362319,
#   'exclamationCount': 0.0,
#   'questionCount': 0.011594202898550725,
#   'sentenceCount': 38.333333333333336,
#   'wordCount': 524.3333333333334,
#   'wordLength': 5.87073532528078},
#  'mehmetBarlas': {'commaCount': 0.5676567656765676,
#   'exclamationCount': 0.0033003300330033004,
#   'questionCount': 0.13036303630363036,
#   'sentenceCount': 33.666666666666664,
#   'wordCount': 463.05555555555554,
#   'wordLength': 6.210437912417516},
#  'mehmetOz': {'commaCount': 0.5221238938053098,
#   'exclamationCount': 0.13274336283185842,
#   'questionCount': 0.06637168141592921,
#   'sentenceCount': 25.11111111111111,
#   'wordCount': 293.55555555555554,
#   'wordLength': 6.114685844057532},
#  'mehmetTezkan': {'commaCount': 0.1498028909329829,
#   'exclamationCount': 0.052562417871222074,
#   'questionCount': 0.06964520367936924,
#   'sentenceCount': 126.83333333333333,
#   'wordCount': 460.3333333333333,
#   'wordLength': 5.617668356263577},
#  'mehmetaliBirand': {'commaCount': 0.8994252873563219,
#   'exclamationCount': 0.005747126436781609,
#   'questionCount': 0.08045977011494253,
#   'sentenceCount': 58.0,
#   'wordCount': 552.6666666666666,
#   'wordLength': 6.0968033775633295},
#  'melihAsik': {'commaCount': 0.3770197486535009,
#   'exclamationCount': 0.04308797127468582,
#   'questionCount': 0.0843806104129264,
#   'sentenceCount': 92.83333333333333,
#   'wordCount': 650.3333333333334,
#   'wordLength': 6.171450538185546},
#  'mumtazerTurkone': {'commaCount': 0.7420814479638009,
#   'exclamationCount': 0.0,
#   'questionCount': 0.17647058823529413,
#   'sentenceCount': 36.833333333333336,
#   'wordCount': 567.6666666666666,
#   'wordLength': 6.349970640046976},
#  'muratBardakci': {'commaCount': 0.9899497487437185,
#   'exclamationCount': 0.04020100502512563,
#   'questionCount': 0.05527638190954774,
#   'sentenceCount': 33.166666666666664,
#   'wordCount': 516.1666666666666,
#   'wordLength': 6.270907329673878},
#  'muratBelge': {'commaCount': 1.5686274509803921,
#   'exclamationCount': 0.07352941176470588,
#   'questionCount': 0.09803921568627451,
#   'sentenceCount': 34.0,
#   'wordCount': 511.3333333333333,
#   'wordLength': 5.817470664928292},
#  'muratYetkin': {'commaCount': 1.0977777777777777,
#   'exclamationCount': 0.0,
#   'questionCount': 0.11555555555555555,
#   'sentenceCount': 37.5,
#   'wordCount': 635.6666666666666,
#   'wordLength': 6.2288935500786575},
#  'nazliIlicak': {'commaCount': 1.232258064516129,
#   'exclamationCount': 0.0064516129032258064,
#   'questionCount': 0.12903225806451613,
#   'sentenceCount': 25.833333333333332,
#   'wordCount': 339.5,
#   'wordLength': 6.13745704467354},
#  'nihalKaraca': {'commaCount': 1.1516587677725119,
#   'exclamationCount': 0.018957345971563982,
#   'questionCount': 0.16587677725118483,
#   'sentenceCount': 35.166666666666664,
#   'wordCount': 550.1666666666666,
#   'wordLength': 6.196607088760982},
#  'nurayMert': {'commaCount': 2.0421686746987953,
#   'exclamationCount': 0.030120481927710843,
#   'questionCount': 0.05421686746987952,
#   'sentenceCount': 27.666666666666668,
#   'wordCount': 479.0,
#   'wordLength': 6.384133611691023},
#  'omerUrundul': {'commaCount': 0.3441295546558704,
#   'exclamationCount': 0.004048582995951417,
#   'questionCount': 0.008097165991902834,
#   'sentenceCount': 41.166666666666664,
#   'wordCount': 440.8333333333333,
#   'wordLength': 5.729678638941399},
#  'oralCalislar': {'commaCount': 0.60062893081761,
#   'exclamationCount': 0.0031446540880503146,
#   'questionCount': 0.03459119496855346,
#   'sentenceCount': 53.0,
#   'wordCount': 594.8333333333334,
#   'wordLength': 6.251891286074531},
#  'raufTamer': {'commaCount': 0.3879781420765027,
#   'exclamationCount': 0.0,
#   'questionCount': 0.16939890710382513,
#   'sentenceCount': 30.5,
#   'wordCount': 188.5,
#   'wordLength': 5.418213969938108},
#  'rehaMuhtar': {'commaCount': 0.27928626842513576,
#   'exclamationCount': 0.010861132660977503,
#   'questionCount': 0.03180760279286268,
#   'sentenceCount': 214.83333333333334,
#   'wordCount': 890.8333333333334,
#   'wordLength': 5.979607109448082},
#  'ridvanDilmen': {'commaCount': 0.30071599045346065,
#   'exclamationCount': 0.00954653937947494,
#   'questionCount': 0.00954653937947494,
#   'sentenceCount': 46.55555555555556,
#   'wordCount': 397.77777777777777,
#   'wordLength': 5.834916201117318},
#  'ruhatMengi': {'commaCount': 0.9716981132075472,
#   'exclamationCount': 0.09748427672955975,
#   'questionCount': 0.18867924528301888,
#   'sentenceCount': 35.333333333333336,
#   'wordCount': 659.1111111111111,
#   'wordLength': 6.068273769386379},
#  'samikohen': {'commaCount': 0.8446771378708552,
#   'exclamationCount': 0.006980802792321117,
#   'questionCount': 0.06108202443280977,
#   'sentenceCount': 31.833333333333332,
#   'wordCount': 448.72222222222223,
#   'wordLength': 6.187198217159836},
#  'savasAy': {'commaCount': 0.5767441860465117,
#   'exclamationCount': 0.018604651162790697,
#   'questionCount': 0.12093023255813953,
#   'sentenceCount': 35.833333333333336,
#   'wordCount': 345.0,
#   'wordLength': 5.806280193236715},
#  'serpilYilmaz': {'commaCount': 0.6153846153846154,
#   'exclamationCount': 0.014245014245014245,
#   'questionCount': 0.06552706552706553,
#   'sentenceCount': 58.5,
#   'wordCount': 663.3333333333334,
#   'wordLength': 5.830150753768844},
#  'tahaAkyol': {'commaCount': 0.7167630057803468,
#   'exclamationCount': 0.21820809248554912,
#   'questionCount': 0.11271676300578035,
#   'sentenceCount': 38.44444444444444,
#   'wordCount': 470.5,
#   'wordLength': 6.167670327075215},
#  'tamerKorkmaz': {'commaCount': 1.4623655913978495,
#   'exclamationCount': 0.3225806451612903,
#   'questionCount': 0.16129032258064516,
#   'sentenceCount': 15.5,
#   'wordCount': 498.8333333333333,
#   'wordLength': 6.189776144336786},
#  'tarhanErdem': {'commaCount': 1.550387596899225,
#   'exclamationCount': 0.06201550387596899,
#   'questionCount': 0.15503875968992248,
#   'sentenceCount': 21.5,
#   'wordCount': 377.1666666666667,
#   'wordLength': 6.73663278833407},
#  'umurTalu': {'commaCount': 0.7702349869451697,
#   'exclamationCount': 0.09399477806788512,
#   'questionCount': 0.06266318537859007,
#   'sentenceCount': 63.833333333333336,
#   'wordCount': 506.8333333333333,
#   'wordLength': 6.084182834593884},
#  'yaseminCongar': {'commaCount': 1.026525198938992,
#   'exclamationCount': 0.0,
#   'questionCount': 0.04774535809018567,
#   'sentenceCount': 62.833333333333336,
#   'wordCount': 744.5,
#   'wordLength': 6.218043429594807},
#  'yigitBulut': {'commaCount': 0.6904761904761905,
#   'exclamationCount': 0.14682539682539683,
#   'questionCount': 0.07539682539682539,
#   'sentenceCount': 42.0,
#   'wordCount': 559.5,
#   'wordLength': 5.784629133154603},
#  'yilmazOzdil': {'commaCount': 0.5751633986928104,
#   'exclamationCount': 0.049019607843137254,
#   'questionCount': 0.08823529411764706,
#   'sentenceCount': 51.0,
#   'wordCount': 265.6666666666667,
#   'wordLength': 5.782308657465496},
#  'yukselAytug': {'commaCount': 0.6040955631399317,
#   'exclamationCount': 0.03754266211604096,
#   'questionCount': 0.07849829351535836,
#   'sentenceCount': 32.55555555555556,
#   'wordCount': 307.77777777777777,
#   'wordLength': 6.025270758122744},
#  'zekiCol': {'commaCount': 0.789308176100629,
#   'exclamationCount': 0.0880503144654088,
#   'questionCount': 0.09119496855345911,
#   'sentenceCount': 53.0,
#   'wordCount': 557.5,
#   'wordLength': 5.952167414050822}}

# %%
currDir
# Out:
# 'zekiCol'
